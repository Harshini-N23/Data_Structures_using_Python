# %%
def LinearSearch(l1, n,key):
    for i in range(0,n):
        if l1[i]==key:
            return i
    return -1

def BSI(l1, key):  
    low = 0  
    high = len(l1)-1 
    mid = 0  
    while low <= high:  
        mid = (high + low) // 2  
        if l1[mid] < key:  
            low = mid + 1  
        elif l1[mid] > key:  
            high = mid - 1  
        else:  
            return mid  
    return -1  

def BSR(l1,low,high, key):
    if high >= low:
        mid = (high + low) // 2
        if l1[mid] == key:
            return mid
        elif l1[mid] > key:
            return BSR(l1, low, mid - 1, key)
        else:
            return BSR(l1, mid + 1, high, key)
    else:
        return -1
    
def main():
    list1 = []
    num = int(input("\n**SEARCHING TECHNIQUES**\nEnter the number of elements in the list: "))
    print("Enter the elements: ")
    for i in range(num):
        ele  = input(">: ")
        list1.append(ele)
    while True:
        try:
           
            
            print("\n*Search Method*\n1.Linear Search\n2.Binary Search\n3.Binary Search using recursion\n4.Exit")
            choice = int(input("\nEnter the Search Method: "))
            if choice ==1:
                print("The elements present in the list are: ", list1)
                k1 = (input("Enter the element to be searched: "))
                LS = LinearSearch(list1, num,k1)
                if LS==-1:
                    print(k1, "not present in the list")
                else:
                    print(k1, "found at index: ",LS)
            elif choice ==2:
                print("The elements present in the list are: ", list1)
                ls = sorted(list1)
                print("The sorted list is: ", ls)
                k2 = (input("Enter the element to be searched: "))
                BS = BSI(ls, k2)
                if BS==-1:
                    print(k2, "not present in the list")
                else:
                    print(k2, "found at index: ",BS)
            elif choice ==3:
                print("The elements present in the list are: ", list1)
                ls2 = sorted(list1)
                print("The sorted list is: ", ls2)
                k3 = (input("Enter the element to be searched: "))
                BS2 = BSR(ls2, 0, len(ls2)-1 ,k3)
                if BS2==-1:
                    print(k3, "not present in the list")
                else:
                    print(k3, "found at index: ",BS2)
            else:
                print("Thank You")
                break
    
        except ValueError:
            print("Invalid Input")
            break



main()
# Out:
# **SEARCHING TECHNIQUES**
# Enter the number of elements in the list: 7
# Enter the elements:
# >: 5
# >: APPLE
# >: apple
# >: @pple
# >: @@
# >: 10.3
# >: 105
#
# *Search Method*
# 1.Linear Search
# 2.Binary Search
# 3.Binary Search using recursion
# 4.Exit
#
# Enter the Search Method: 2
# The elements present in the list are:  ['5', 'APPLE', 'apple', '@pple', '@@', '10.3', '105']
# The sorted list is:  ['10.3', '105', '5', '@@', '@pple', 'APPLE', 'apple']
# Enter the element to be searched: apple
# apple found at index:  6
#
# *Search Method*
# 1.Linear Search
# 2.Binary Search
# 3.Binary Search using recursion
# 4.Exit
#
# Enter the Search Method: 2
# The elements present in the list are:  ['5', 'APPLE', 'apple', '@pple', '@@', '10.3', '105']
# The sorted list is:  ['10.3', '105', '5', '@@', '@pple', 'APPLE', 'apple']
# Enter the element to be searched: 100
# 100 not present in the list
#
# *Search Method*
# 1.Linear Search
# 2.Binary Search
# 3.Binary Search using recursion
# ...

# %%
def LinearSearch(l1, n,key):
    for i in range(0,n):
        if l1[i]==key:
            return i
    return -1

def BSI(l1, key):  
    low = 0  
    high = len(l1)-1 
    mid = 0  
    while low <= high:  
        mid = (high + low) // 2  
        if l1[mid] < key:  
            low = mid + 1  
        elif l1[mid] > key:  
            high = mid - 1  
        else:  
            return mid  
    return -1  

def BSR(l1,low,high, key):
    if high >= low:
        mid = (high + low) // 2
        if l1[mid] == key:
            return mid
        elif l1[mid] > key:
            return BSR(l1, low, mid - 1, key)
        else:
            return BSR(l1, mid + 1, high, key)
    else:
        return -1
    
def main():
    try:
        list1 = []
        num = int(input("\n**SEARCHING TECHNIQUES**\nEnter the number of elements in the list: "))
        if num<=1:
            print()
            raise ValueError("Elements in the list should be atleast 2")
        print("Enter the elements: ")
        for i in range(num):
            ele  = int(input(">: "))
            list1.append(ele)
        while True:
            print("\n*Search Method*\n1.Linear Search\n2.Binary Search\n3.Binary Search using recursion\n4.Exit")
            choice = int(input("\nEnter the Search Method: "))
            if choice ==1:
                print("The elements present in the list are: ", list1)
                k1 = int(input("Enter the element to be searched: "))
                LS = LinearSearch(list1, num,k1)
                if LS==-1:
                    print(k1, "not present in the list")
                else:
                    print(k1, "found at index: ",LS)
            elif choice ==2:
                #print("The elements present in the list are: ", list1)
                ls = sorted(list1)
                print("The sorted list is: ", ls)
                k2 = int(input("Enter the element to be searched: "))
                BS = BSI(ls, k2)
                if BS==-1:
                    print(k2, "not present in the list")
                else:
                    print(k2, "found at index: ",BS)
            elif choice ==3:
                #print("The elements present in the list are: ", list1)
                ls2 = sorted(list1)
                print("The sorted list is: ", ls2)
                k3 = int(input("Enter the element to be searched: "))
                BS2 = BSR(ls2, 0, len(ls2)-1 ,k3)
                if BS2==-1:
                    print(k3, "not present in the list")
                else:
                    print(k3, "found at index: ",BS2)
            else:
                print("Thank You")
                break
    except ValueError:
        print("Invalid Input")

# %%
main()
# Out:
# **SEARCHING TECHNIQUES**
# Enter the number of elements in the list: 3
# Enter the elements:
# >: po
# Invalid Input
